# %%
import pandas as pd
import numpy as np

# %%
全地院整合完整rawdata = pd.read_csv('/Users/allentsai/Git_Project/judgement/judgement_file/judge案由分類/原始資料完整rawdata/全地院整合完整rawdata.csv'
                             ,encoding='utf-8')
print(f'資料總筆數：{len(全地院整合完整rawdata)}筆')
全地院整合完整rawdata.drop('judge_link',axis=1)
# Out:
# 資料總筆數：211073筆
#        judge_court  judge_year  judge_month  judge_index     judge_title  \
# 0         臺灣彰化地方法院         111            1            1            過失傷害
# 1         臺灣彰化地方法院         111            1            2            過失傷害
# 2         臺灣彰化地方法院         111            1            3            過失傷害
# 3         臺灣彰化地方法院         111            1            4            過失傷害
# 4         臺灣彰化地方法院         111            1            5            過失傷害
# ...            ...         ...          ...          ...             ...
# 211068    臺灣南投地方法院         102           12           16          業務過失傷害
# 211069    臺灣南投地方法院         102           12           17  因過失傷害案提起附帶民事訴訟
# 211070    臺灣南投地方法院         102           12           18            過失傷害
# 211071    臺灣南投地方法院         102           12           19            過失傷害
# 211072    臺灣南投地方法院         102           12           20              傷害
#
#                                judge_NO  \
# ...

# %%
原始資料完整rawdata = pd.read_csv('/Users/allentsai/Git_Project/judgement/judgement_file/judge案由分類/原始資料完整rawdata/原始資料完整rawdata.csv',encoding='utf-8')
原始資料完整rawdata

# %%
所有地院10年_rawdata_1215 = pd.read_csv('/Users/allentsai/Git_Project/judgement/judgement_file/judge案由分類/清整過程留存/1215_所有地院10年_rawdata.csv',encoding='utf-8')
print(f'資料總筆數：{len(所有地院10年_rawdata_1215)}筆')
所有地院10年_rawdata_1215
# Out:
# 資料總筆數：66588筆
#       judge_court  judge_year  judge_month  judge_index judge_title  \
# 0        臺灣彰化地方法院         111            1            4        過失傷害
# 1        臺灣彰化地方法院         111            1            6      傷害致重傷害
# 2        臺灣彰化地方法院         111            1           18         重傷害
# 3        臺灣彰化地方法院         111            1           19          傷害
# 4        臺灣彰化地方法院         111            1           27          傷害
# ...           ...         ...          ...          ...         ...
# 66583    臺灣南投地方法院         102           11           20        過失傷害
# 66584    臺灣南投地方法院         102           11           27          傷害
# 66585    臺灣南投地方法院         102           12            3      業務過失傷害
# 66586    臺灣南投地方法院         102           12            5         傷害等
# 66587    臺灣南投地方法院         102           12           18        過失傷害
#
#                                            judge_content        judge_crime  \
# ...
